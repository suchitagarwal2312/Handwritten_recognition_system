# %% [markdown]
# <a href="https://colab.research.google.com/github/prachi1234bansal/mnist_784/blob/master/mnist_784.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np;

# %%
import pandas as pd;

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
dataset=fetch_openml('mnist_784')
X=dataset.data
y=dataset.target
X.shape#1d array so not able to represent
some_digit=X[40000]
some_digit_image=some_digit.reshape(28,28)
plt.imshow(some_digit_image)
plt.show()

# %%
y[40000]
y=y.astype(int)
y[36000]
# Out:
# 9

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)
len(X_test)
# Out:
# 17500

# %%
len(y_test)
# Out:
# 17500

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
print(lr.score(X_train,y_train))
# Out:
# 0.6202541972474265

# %%
from sklearn.linear_model import LogisticRegression
lr1=LogisticRegression()
lr1.fit(X_train,y_train)
print(lr1.score(X_train,y_train))
# Out:
# 0.9358095238095238
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
print(dt.score(X_train,y_train))
# Out:
# 1.0

# %%
y_pred=dt.predict(X_train)
from sklearn.metrics import confusion_matrix,precision_score,recall_score
cm=confusion_matrix(y_train,y_pred)
cm
y_pred
# Out:
# array([6, 9, 1, ..., 7, 1, 1])

# %%
for i in range(12):
  plt.subplot(3,4,i+1)
  img=X_train[i]
  img=img.reshape(28,28)
  plt.imshow(img,'binary')
 
plt.show()

# %%
for i in range(12):
  plt.subplot(3,4,i+1)
  plt.xticks([])
  plt.yticks([])
  img=X_train[i]
  img=img.reshape(28,28)
  plt.imshow(img,'binary')
  plt.xlabel('Actual: {} \n Predicted :{}'.format(y_train[i],y_pred[i]))
plt.show()

# %%
for i in range(12):
  plt.subplot(3,4,i+1)
  plt.xticks([])
  plt.yticks([])
  img=X_train[i]
  img=img.reshape(28,28)
  plt.imshow(img,'binary')
  plt.xlabel('Actual: {} \n Predicted :{}'.format(y_train[i],y_pred[i]))
plt.show()

# %%
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    img = X[i]
    img = img.reshape(28, 28)
    plt.imshow(img)
    plt.xlabel('Actual : {} \nPredicted : {}'.format(y_train[i], y_pred[i]))
plt.tight_layout()
plt.show()

# %%
y_pred
# Out:
# array([6, 9, 1, ..., 7, 1, 1])
